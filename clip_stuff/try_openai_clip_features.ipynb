# %%
# !git clone https://github.com/jianjieluo/OpenAI-CLIP-Feature.git
# Out:
# Cloning into 'OpenAI-CLIP-Feature'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 42 (delta 0), reused 1 (delta 0), pack-reused 39
# Receiving objects: 100% (42/42), 2.23 MiB | 3.25 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# !pip install ftfy
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 OpenAI-CLIP-Feature/clip_visual_feats.py \
    --image_list 'list.txt' \
    --image_dir 'OpenAI-CLIP-Feature/example' \
    --output_dir 'output' \
    --ve_name 'ViT-B/16' \
    --model_type_or_path 'ViT-B/16'
# Out:
# Called with args:
# { 'anno': None,
#   'debug': False,
#   'image_dir': 'OpenAI-CLIP-Feature/example',
#   'image_list': 'list.txt',
#   'model_type_or_path': 'ViT-B/16',
#   'output_dir': 'output',
#   've_name': 'ViT-B/16'}
# ligma
# here22
# here
# 100%|███████████████████████████████████████| 335M/335M [00:03<00:00, 89.0MiB/s]
# 100% 1/1 [00:00<00:00,  1.09it/s]

# %%
import numpy as np


# Replace 'your_file.npz' with the path to your file
data = np.load('output/123.npz')

# List all arrays in the file
for file in data.files:
    print(file)
# Out:
# features
# g_feature

# %%
import numpy as np

# Load the .npz file
data = np.load('mynpz.npz')
global_features = data['features']
grid_features = data['g_feature']

# %%
global_features.shape
# Out:
# (49, 768)

# %%
from PIL import Image
import matplotlib.pyplot as plt
# Load your original image
original_image = Image.open('bluefork.png')

# Obtain dimensions
new_width, new_height = original_image.size
import numpy as np

# Assuming 'grid_features' is your array of features extracted from the model
# Resize grid features to match the original image dimensions
resized_grid_features = np.resize(grid_features, (new_height, new_width))
# Create a heatmap
plt.imshow(original_image, cmap='gray')  # Display the original image

# %%
plt.imshow(grid_features, cmap='hot', alpha=0.5)  # Overlay the heatmap
